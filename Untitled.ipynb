# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
data = pd.read_csv("Fish.csv")

# %%
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
data.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
y = data.Weight.values.reshape(-1,1)

# %%
y
# Out:
# array([[ 242. ],
#        [ 290. ],
#        [ 340. ],
#        [ 363. ],
#        [ 430. ],
#        [ 450. ],
#        [ 500. ],
#        [ 390. ],
#        [ 450. ],
#        [ 500. ],
#        [ 475. ],
#        [ 500. ],
#        [ 500. ],
#        [ 340. ],
#        [ 600. ],
#        [ 600. ],
#        [ 700. ],
#        [ 700. ],
#        [ 610. ],
#        [ 650. ],
#        [ 575. ],
#        [ 685. ],
#        [ 620. ],
#        [ 680. ],
#        [ 700. ],
#        [ 725. ],
#        [ 720. ],
#        [ 714. ],
#        [ 850. ],
#        [1000. ],
#        [ 920. ],
#        [ 955. ],
#        [ 925. ],
#        [ 975. ],
#        [ 950. ],
#        [  40. ],
#        [  69. ],
#        [  78. ],
#        [  87. ],
#        [ 120. ],
#        [   0. ],
#        [ 110. ],
#        [ 120. ],
#        [ 150. ],
#        [ 145. ],
#        [ 160. ],
#        [ 140. ],
#        [ 160. ],
#        [ 169. ],
#        [ 161. ],
#        [ 200. ],
#        [ 180. ],
#        [ 290. ],
#        [ 272. ],
#        [ 390. ],
#        [ 270. ],
#        [ 270. ],
#        [ 306. ],
#        [ 540. ],
#        [ 800. ],
#        [1000. ],
#        [  55. ],
#        [  60. ],
#        [  90. ],
#        [ 120. ],
#        [ 150. ],
#        [ 140. ],
#        [ 170. ],
#        [ 145. ],
#        [ 200. ],
#        [ 273. ],
#        [ 300. ],
#        [   5.9],
#        [  32. ],
#        [  40. ],
#        [  51.5],
#        [  70. ],
#        [ 100. ],
#        [  78. ],
#        [  80. ],
#        [  85. ],
#        [  85. ],
#        [ 110. ],
#        [ 115. ],
#        [ 125. ],
#        [ 130. ],
#        [ 120. ],
#        [ 120. ],
#        [ 130. ],
#        [ 135. ],
#        [ 110. ],
#        [ 130. ],
#        [ 150. ],
#        [ 145. ],
#        [ 150. ],
#        [ 170. ],
#        [ 225. ],
#        [ 145. ],
#        [ 188. ],
#        [ 180. ],
#        [ 197. ],
#        [ 218. ],
#        [ 300. ],
#        [ 260. ],
#        [ 265. ],
#        [ 250. ],
#        [ 250. ],
#        [ 300. ],
#        [ 320. ],
#        [ 514. ],
#        [ 556. ],
#        [ 840. ],
#        [ 685. ],
#        [ 700. ],
#        [ 700. ],
#        [ 690. ],
#        [ 900. ],
#        [ 650. ],
#        [ 820. ],
#        [ 850. ],
#        [ 900. ],
#        [1015. ],
#        [ 820. ],
#        [1100. ],
#        [1000. ],
#        [1100. ],
#        [1000. ],
#        [1000. ],
#        [ 200. ],
#        [ 300. ],
#        [ 300. ],
#        [ 300. ],
#        [ 430. ],
#        [ 345. ],
#        [ 456. ],
#        [ 510. ],
#        [ 540. ],
#        [ 500. ],
#        [ 567. ],
#        [ 770. ],
#        [ 950. ],
#        [1250. ],
#        [1600. ],
#        [1550. ],
#        [1650. ],
#        [   6.7],
#        [   7.5],
#        [   7. ],
#        [   9.7],
#        [   9.8],
#        [   8.7],
#        [  10. ],
#        [   9.9],
#        [   9.8],
#        [  12.2],
#        [  13.4],
#        [  12.2],
#        [  19.7],
#        [  19.9]])

# %%
x = data.Width.values.reshape(-1,1)

# %%
x
# Out:
# array([[4.02  ],
#        [4.3056],
#        [4.6961],
#        [4.4555],
#        [5.134 ],
#        [4.9274],
#        [5.2785],
#        [4.69  ],
#        [4.8438],
#        [4.9594],
#        [5.1042],
#        [4.8146],
#        [4.368 ],
#        [5.0728],
#        [5.1708],
#        [5.58  ],
#        [5.2854],
#        [5.1975],
#        [5.1338],
#        [5.7276],
#        [5.5695],
#        [5.3704],
#        [5.2801],
#        [6.1306],
#        [5.589 ],
#        [6.0532],
#        [6.09  ],
#        [5.8515],
#        [6.1984],
#        [6.603 ],
#        [6.3063],
#        [6.292 ],
#        [6.7497],
#        [6.7473],
#        [6.3705],
#        [2.268 ],
#        [2.8217],
#        [2.9044],
#        [3.1746],
#        [3.5742],
#        [3.3516],
#        [3.3957],
#        [3.2943],
#        [3.7544],
#        [3.5478],
#        [3.8203],
#        [3.325 ],
#        [3.8   ],
#        [3.8352],
#        [3.6312],
#        [4.1272],
#        [3.906 ],
#        [4.4968],
#        [4.7736],
#        [5.355 ],
#        [4.2476],
#        [4.2485],
#        [4.6816],
#        [6.562 ],
#        [6.5736],
#        [6.525 ],
#        [2.3265],
#        [2.3142],
#        [2.673 ],
#        [2.9181],
#        [3.2928],
#        [3.2944],
#        [3.4104],
#        [3.1571],
#        [3.6636],
#        [4.144 ],
#        [4.234 ],
#        [1.408 ],
#        [1.9992],
#        [2.432 ],
#        [2.6316],
#        [2.9415],
#        [3.3216],
#        [3.1234],
#        [3.0502],
#        [3.0368],
#        [2.772 ],
#        [3.555 ],
#        [3.3075],
#        [3.6675],
#        [3.534 ],
#        [3.4075],
#        [3.525 ],
#        [3.525 ],
#        [3.525 ],
#        [3.995 ],
#        [3.624 ],
#        [3.624 ],
#        [3.63  ],
#        [3.626 ],
#        [3.725 ],
#        [3.723 ],
#        [3.825 ],
#        [4.1658],
#        [3.6835],
#        [4.239 ],
#        [4.144 ],
#        [5.1373],
#        [4.335 ],
#        [4.335 ],
#        [4.5662],
#        [4.2042],
#        [4.6354],
#        [4.7716],
#        [6.018 ],
#        [6.3875],
#        [7.7957],
#        [6.864 ],
#        [6.7408],
#        [6.2646],
#        [6.3666],
#        [7.4934],
#        [6.003 ],
#        [7.3514],
#        [7.1064],
#        [7.225 ],
#        [7.4624],
#        [6.63  ],
#        [6.8684],
#        [7.2772],
#        [7.4165],
#        [8.142 ],
#        [7.5958],
#        [3.3756],
#        [4.158 ],
#        [4.3844],
#        [4.0198],
#        [4.5765],
#        [3.977 ],
#        [4.3225],
#        [4.459 ],
#        [5.1296],
#        [4.896 ],
#        [4.87  ],
#        [5.376 ],
#        [6.1712],
#        [6.9849],
#        [6.144 ],
#        [6.144 ],
#        [7.48  ],
#        [1.0476],
#        [1.16  ],
#        [1.1484],
#        [1.38  ],
#        [1.2772],
#        [1.2852],
#        [1.2838],
#        [1.1659],
#        [1.1484],
#        [1.3936],
#        [1.269 ],
#        [1.2558],
#        [2.0672],
#        [1.8792]])

# %%
plt.scatter(x,y)
plt.xlabel("diagonal width in cm")
plt.ylabel("weight of fish in gram")
# Out:
# Text(0, 0.5, 'weight of fish in gram')

# %%
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_head = lr.predict(x)
plt.plot(x,y_head,color= "red",label="linear")
plt.show()
print("Predict weight of fish in 800 Gram: ", lr.predict([[800]]))
# Out:
# Predict weight of fish in 800 Gram:  [[150165.58496564]]

# %%
#####Polynomial Regression
pr = PolynomialFeatures(degree = 2)

# %%
x_p = pr.fit_transform(x)

# %%
x_p
# Out:
# array([[ 1.        ,  4.02      , 16.1604    ],
#        [ 1.        ,  4.3056    , 18.53819136],
#        [ 1.        ,  4.6961    , 22.05335521],
#        [ 1.        ,  4.4555    , 19.85148025],
#        [ 1.        ,  5.134     , 26.357956  ],
#        [ 1.        ,  4.9274    , 24.27927076],
#        [ 1.        ,  5.2785    , 27.86256225],
#        [ 1.        ,  4.69      , 21.9961    ],
#        [ 1.        ,  4.8438    , 23.46239844],
#        [ 1.        ,  4.9594    , 24.59564836],
#        [ 1.        ,  5.1042    , 26.05285764],
#        [ 1.        ,  4.8146    , 23.18037316],
#        [ 1.        ,  4.368     , 19.079424  ],
#        [ 1.        ,  5.0728    , 25.73329984],
#        [ 1.        ,  5.1708    , 26.73717264],
#        [ 1.        ,  5.58      , 31.1364    ],
#        [ 1.        ,  5.2854    , 27.93545316],
#        [ 1.        ,  5.1975    , 27.01400625],
#        [ 1.        ,  5.1338    , 26.35590244],
#        [ 1.        ,  5.7276    , 32.80540176],
#        [ 1.        ,  5.5695    , 31.01933025],
#        [ 1.        ,  5.3704    , 28.84119616],
#        [ 1.        ,  5.2801    , 27.87945601],
#        [ 1.        ,  6.1306    , 37.58425636],
#        [ 1.        ,  5.589     , 31.236921  ],
#        [ 1.        ,  6.0532    , 36.64123024],
#        [ 1.        ,  6.09      , 37.0881    ],
#        [ 1.        ,  5.8515    , 34.24005225],
#        [ 1.        ,  6.1984    , 38.42016256],
#        [ 1.        ,  6.603     , 43.599609  ],
#        [ 1.        ,  6.3063    , 39.76941969],
#        [ 1.        ,  6.292     , 39.589264  ],
#        [ 1.        ,  6.7497    , 45.55845009],
#        [ 1.        ,  6.7473    , 45.52605729],
#        [ 1.        ,  6.3705    , 40.58327025],
#        [ 1.        ,  2.268     ,  5.143824  ],
#        [ 1.        ,  2.8217    ,  7.96199089],
#        [ 1.        ,  2.9044    ,  8.43553936],
#        [ 1.        ,  3.1746    , 10.07808516],
#        [ 1.        ,  3.5742    , 12.77490564],
#        [ 1.        ,  3.3516    , 11.23322256],
#        [ 1.        ,  3.3957    , 11.53077849],
#        [ 1.        ,  3.2943    , 10.85241249],
#        [ 1.        ,  3.7544    , 14.09551936],
#        [ 1.        ,  3.5478    , 12.58688484],
#        [ 1.        ,  3.8203    , 14.59469209],
#        [ 1.        ,  3.325     , 11.055625  ],
#        [ 1.        ,  3.8       , 14.44      ],
#        [ 1.        ,  3.8352    , 14.70875904],
#        [ 1.        ,  3.6312    , 13.18561344],
#        [ 1.        ,  4.1272    , 17.03377984],
#        [ 1.        ,  3.906     , 15.256836  ],
#        [ 1.        ,  4.4968    , 20.22121024],
#        [ 1.        ,  4.7736    , 22.78725696],
#        [ 1.        ,  5.355     , 28.676025  ],
#        [ 1.        ,  4.2476    , 18.04210576],
#        [ 1.        ,  4.2485    , 18.04975225],
#        [ 1.        ,  4.6816    , 21.91737856],
#        [ 1.        ,  6.562     , 43.059844  ],
#        [ 1.        ,  6.5736    , 43.21221696],
#        [ 1.        ,  6.525     , 42.575625  ],
#        [ 1.        ,  2.3265    ,  5.41260225],
#        [ 1.        ,  2.3142    ,  5.35552164],
#        [ 1.        ,  2.673     ,  7.144929  ],
#        [ 1.        ,  2.9181    ,  8.51530761],
#        [ 1.        ,  3.2928    , 10.84253184],
#        [ 1.        ,  3.2944    , 10.85307136],
#        [ 1.        ,  3.4104    , 11.63082816],
#        [ 1.        ,  3.1571    ,  9.96728041],
#        [ 1.        ,  3.6636    , 13.42196496],
#        [ 1.        ,  4.144     , 17.172736  ],
#        [ 1.        ,  4.234     , 17.926756  ],
#        [ 1.        ,  1.408     ,  1.982464  ],
#        [ 1.        ,  1.9992    ,  3.99680064],
#        [ 1.        ,  2.432     ,  5.914624  ],
#        [ 1.        ,  2.6316    ,  6.92531856],
#        [ 1.        ,  2.9415    ,  8.65242225],
#        [ 1.        ,  3.3216    , 11.03302656],
#        [ 1.        ,  3.1234    ,  9.75562756],
#        [ 1.        ,  3.0502    ,  9.30372004],
#        [ 1.        ,  3.0368    ,  9.22215424],
#        [ 1.        ,  2.772     ,  7.683984  ],
#        [ 1.        ,  3.555     , 12.638025  ],
#        [ 1.        ,  3.3075    , 10.93955625],
#        [ 1.        ,  3.6675    , 13.45055625],
#        [ 1.        ,  3.534     , 12.489156  ],
#        [ 1.        ,  3.4075    , 11.61105625],
#        [ 1.        ,  3.525     , 12.425625  ],
#        [ 1.        ,  3.525     , 12.425625  ],
#        [ 1.        ,  3.525     , 12.425625  ],
#        [ 1.        ,  3.995     , 15.960025  ],
#        [ 1.        ,  3.624     , 13.133376  ],
#        [ 1.        ,  3.624     , 13.133376  ],
#        [ 1.        ,  3.63      , 13.1769    ],
#        [ 1.        ,  3.626     , 13.147876  ],
#        [ 1.        ,  3.725     , 13.875625  ],
#        [ 1.        ,  3.723     , 13.860729  ],
#        [ 1.        ,  3.825     , 14.630625  ],
#        [ 1.        ,  4.1658    , 17.35388964],
#        [ 1.        ,  3.6835    , 13.56817225],
#        [ 1.        ,  4.239     , 17.969121  ],
#        [ 1.        ,  4.144     , 17.172736  ],
#        [ 1.        ,  5.1373    , 26.39185129],
#        [ 1.        ,  4.335     , 18.792225  ],
#        [ 1.        ,  4.335     , 18.792225  ],
#        [ 1.        ,  4.5662    , 20.85018244],
#        [ 1.        ,  4.2042    , 17.67529764],
#        [ 1.        ,  4.6354    , 21.48693316],
#        [ 1.        ,  4.7716    , 22.76816656],
#        [ 1.        ,  6.018     , 36.216324  ],
#        [ 1.        ,  6.3875    , 40.80015625],
#        [ 1.        ,  7.7957    , 60.77293849],
#        [ 1.        ,  6.864     , 47.114496  ],
#        [ 1.        ,  6.7408    , 45.43838464],
#        [ 1.        ,  6.2646    , 39.24521316],
#        [ 1.        ,  6.3666    , 40.53359556],
#        [ 1.        ,  7.4934    , 56.15104356],
#        [ 1.        ,  6.003     , 36.036009  ],
#        [ 1.        ,  7.3514    , 54.04308196],
#        [ 1.        ,  7.1064    , 50.50092096],
#        [ 1.        ,  7.225     , 52.200625  ],
#        [ 1.        ,  7.4624    , 55.68741376],
#        [ 1.        ,  6.63      , 43.9569    ],
#        [ 1.        ,  6.8684    , 47.17491856],
#        [ 1.        ,  7.2772    , 52.95763984],
#        [ 1.        ,  7.4165    , 55.00447225],
#        [ 1.        ,  8.142     , 66.292164  ],
#        [ 1.        ,  7.5958    , 57.69617764],
#        [ 1.        ,  3.3756    , 11.39467536],
#        [ 1.        ,  4.158     , 17.288964  ],
#        [ 1.        ,  4.3844    , 19.22296336],
#        [ 1.        ,  4.0198    , 16.15879204],
#        [ 1.        ,  4.5765    , 20.94435225],
#        [ 1.        ,  3.977     , 15.816529  ],
#        [ 1.        ,  4.3225    , 18.68400625],
#        [ 1.        ,  4.459     , 19.882681  ],
#        [ 1.        ,  5.1296    , 26.31279616],
#        [ 1.        ,  4.896     , 23.970816  ],
#        [ 1.        ,  4.87      , 23.7169    ],
#        [ 1.        ,  5.376     , 28.901376  ],
#        [ 1.        ,  6.1712    , 38.08370944],
#        [ 1.        ,  6.9849    , 48.78882801],
#        [ 1.        ,  6.144     , 37.748736  ],
#        [ 1.        ,  6.144     , 37.748736  ],
#        [ 1.        ,  7.48      , 55.9504    ],
#        [ 1.        ,  1.0476    ,  1.09746576],
#        [ 1.        ,  1.16      ,  1.3456    ],
#        [ 1.        ,  1.1484    ,  1.31882256],
#        [ 1.        ,  1.38      ,  1.9044    ],
#        [ 1.        ,  1.2772    ,  1.63123984],
#        [ 1.        ,  1.2852    ,  1.65173904],
#        [ 1.        ,  1.2838    ,  1.64814244],
#        [ 1.        ,  1.1659    ,  1.35932281],
#        [ 1.        ,  1.1484    ,  1.31882256],
#        [ 1.        ,  1.3936    ,  1.94212096],
#        [ 1.        ,  1.269     ,  1.610361  ],
#        [ 1.        ,  1.2558    ,  1.57703364],
#        [ 1.        ,  2.0672    ,  4.27331584],
#        [ 1.        ,  1.8792    ,  3.53139264]])

# %%
lr2 = LinearRegression()
lr2.fit(x_p,y)
# Out:
# LinearRegression()

# %%
y_head2 = lr2.predict(x_p)

# %%
y_head2
# Out:
# array([[ 266.40132914],
#        [ 316.99491737],
#        [ 391.83280114],
#        [ 344.94932231],
#        [ 483.53345415],
#        [ 439.2446342 ],
#        [ 515.59781273],
#        [ 390.61347728],
#        [ 421.84354374],
#        [ 445.98466215],
#        [ 477.03225371],
#        [ 415.83628036],
#        [ 328.51462666],
#        [ 470.2232029 ],
#        [ 491.61433744],
#        [ 585.38373755],
#        [ 517.15131467],
#        [ 497.51372584],
#        [ 483.48969498],
#        [ 620.96901618],
#        [ 582.88786161],
#        [ 536.45616256],
#        [ 515.95786322],
#        [ 722.88748102],
#        [ 587.5268231 ],
#        [ 702.77266132],
#        [ 712.30425835],
#        [ 651.56173018],
#        [ 740.71854033],
#        [ 851.22485179],
#        [ 769.50222298],
#        [ 765.65881647],
#        [ 893.02651745],
#        [ 892.33521933],
#        [ 786.86530518],
#        [  32.58760623],
#        [  92.25414123],
#        [ 102.29443959],
#        [ 137.14311931],
#        [ 194.42036301],
#        [ 161.66879547],
#        [ 167.98851424],
#        [ 153.58205113],
#        [ 222.48999738],
#        [ 190.42501005],
#        [ 233.10296568],
#        [ 157.89722851],
#        [ 229.81387077],
#        [ 235.52837557],
#        [ 203.14863095],
#        [ 284.98154546],
#        [ 247.18325125],
#        [ 352.8205656 ],
#        [ 407.46314267],
#        [ 532.93559444],
#        [ 306.43723892],
#        [ 306.59996299],
#        [ 388.93702017],
#        [ 839.70706342],
#        [ 842.9584417 ],
#        [ 829.3748474 ],
#        [  38.27034903],
#        [  37.0633305 ],
#        [  74.93887943],
#        [ 103.98602535],
#        [ 153.37224756],
#        [ 153.59604147],
#        [ 170.11362199],
#        [ 134.79125234],
#        [ 208.17207433],
#        [ 287.93804132],
#        [ 303.98252609],
#        [ -34.01520417],
#        [   8.36268529],
#        [  48.88972817],
#        [  70.28684962],
#        [ 106.89391909],
#        [ 157.41733575],
#        [ 130.29922784],
#        [ 120.70986717],
#        [ 118.97932155],
#        [  86.36135337],
#        [ 191.51168743],
#        [ 155.43248342],
#        [ 208.77978381],
#        [ 188.34842604],
#        [ 169.69364925],
#        [ 186.99853231],
#        [ 186.99853231],
#        [ 186.99853231],
#        [ 262.13912678],
#        [ 202.03842414],
#        [ 202.03842414],
#        [ 202.96344209],
#        [ 202.34659191],
#        [ 217.8153091 ],
#        [ 217.49864974],
#        [ 233.86699986],
#        [ 291.79249087],
#        [ 211.27977851],
#        [ 304.88407198],
#        [ 287.93804132],
#        [ 484.255728  ],
#        [ 322.40166831],
#        [ 322.40166831],
#        [ 366.21204446],
#        [ 298.63155029],
#        [ 379.7705975 ],
#        [ 407.05654106],
#        [ 693.70982773],
#        [ 791.49260657],
#        [1217.83269054],
#        [ 926.2356197 ],
#        [ 890.46419411],
#        [ 758.31902789],
#        [ 785.80549566],
#        [1119.14092449],
#        [ 689.86397167],
#        [1074.13511624],
#        [ 998.51740702],
#        [1034.80109211],
#        [1109.24192605],
#        [ 858.84910692],
#        [ 927.5252098 ],
#        [1050.96199279],
#        [1094.66071093],
#        [1335.70552855],
#        [1152.13247205],
#        [ 165.0977539 ],
#        [ 290.41103427],
#        [ 331.56995431],
#        [ 266.36712516],
#        [ 368.21714371],
#        [ 259.08693828],
#        [ 320.09834973],
#        [ 345.61353986],
#        [ 482.57114884],
#        [ 432.67367046],
#        [ 427.26474722],
#        [ 537.73889089],
#        [ 733.54139662],
#        [ 961.97206591],
#        [ 726.3959823 ],
#        [ 726.3959823 ],
#        [1114.85694537],
#        [ -52.49492608],
#        [ -47.3292894 ],
#        [ -47.88747116],
#        [ -35.65049876],
#        [ -41.36603277],
#        [ -40.93750682],
#        [ -41.012697  ],
#        [ -47.04317257],
#        [ -47.88747116],
#        [ -34.86041229],
#        [ -41.80242334],
#        [ -42.49884837],
#        [  14.19821658],
#        [  -1.45154771]])

# %%
plt.plot(x,y_head2,color = "green",label = "poly")
plt.legend()
plt.show()

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %%
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
data.isna().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
X = data.drop('Species',axis =1)
y = data['Species']
X
y
# Out:
# 0      Bream
# 1      Bream
# 2      Bream
# 3      Bream
# 4      Bream
#        ...
# 154    Smelt
# 155    Smelt
# 156    Smelt
# 157    Smelt
# 158    Smelt
# Name: Species, Length: 159, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score

# %%
x_train
# Out:
#     Species  Weight  Length1  Length2  Length3   Height
# 53    Roach   272.0     25.0     27.0     30.6   8.5680
# 117   Perch   650.0     36.5     39.0     41.4  11.1366
# 136    Pike   540.0     40.1     43.0     45.8   7.7860
# 17    Bream   700.0     30.4     33.0     38.5  14.9380
# 77    Perch   100.0     16.2     18.0     19.2   5.2224
# ..      ...     ...      ...      ...      ...      ...
# 133    Pike   345.0     36.0     38.5     41.0   6.3960
# 137    Pike   500.0     42.0     45.0     48.0   6.9600
# 72    Perch     5.9      7.5      8.4      8.8   2.1120
# 140    Pike   950.0     48.3     51.7     55.1   8.9262
# 37    Roach    78.0     17.5     18.8     21.2   5.5756
#
# [111 rows x 6 columns]

# %%
y_train
# Out:
# 53     Roach
# 117    Perch
# 136     Pike
# 17     Bream
# 77     Perch
#        ...
# 133     Pike
# 137     Pike
# 72     Perch
# 140     Pike
# 37     Roach
# Name: Species, Length: 111, dtype: object

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
prediction_dt = tree.predict(X_test)
print(classification_report(y_test, prediction_dt))
# Out:
#               precision    recall  f1-score   support
#
#        Bream       1.00      0.80      0.89        10
#       Parkki       0.50      1.00      0.67         2
#        Perch       0.65      0.65      0.65        20
#         Pike       0.75      1.00      0.86         3
#        Roach       0.50      0.43      0.46         7
#        Smelt       0.50      0.67      0.57         3
#    Whitefish       0.00      0.00      0.00         3
#
#     accuracy                           0.65        48
#    macro avg       0.56      0.65      0.59        48
# weighted avg       0.65      0.65      0.64        48

# %%
print(confusion_matrix(y_test, prediction_dt))
# Out:
# [[ 8  0  2  0  0  0  0]
#  [ 0  2  0  0  0  0  0]
#  [ 0  1 13  1  3  1  1]
#  [ 0  0  0  3  0  0  0]
#  [ 0  0  2  0  3  1  1]
#  [ 0  0  1  0  0  2  0]
#  [ 0  1  2  0  0  0  0]]

# %%
from matplotlib import pyplot as plt
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %%
clf = DecisionTreeClassifier(random_state=1234)
model = clf.fit(X, y)

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_4 <= 12.64
# |   |--- feature_4 <= 3.23
# |   |   |--- feature_2 <= 9.10
# |   |   |   |--- class: Perch
# |   |   |--- feature_2 >  9.10
# |   |   |   |--- class: Smelt
# |   |--- feature_4 >  3.23
# |   |   |--- feature_3 <= 47.30
# |   |   |   |--- feature_5 <= 5.68
# |   |   |   |   |--- feature_2 <= 32.00
# |   |   |   |   |   |--- feature_4 <= 8.35
# |   |   |   |   |   |   |--- feature_5 <= 4.14
# |   |   |   |   |   |   |   |--- feature_4 <= 6.11
# |   |   |   |   |   |   |   |   |--- feature_3 <= 24.60
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.92
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 5.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  5.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Roach
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.92
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  3.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Perch
# |   |   |   |   |   |   |   |   |--- feature_3 >  24.60
# |   |   |   |   |   |   |   |   |   |--- class: Roach
# |   |   |   |   |   |   |   |--- feature_4 >  6.11
# |   |   |   |   |   |   |   |   |--- feature_2 <= 18.85
# |   |   |   |   |   |   |   |   |   |--- class: Parkki
# |   |   |   |   |   |   |   |   |--- feature_2 >  18.85
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 23.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 24.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  24.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Roach
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  23.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 26.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Perch
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  26.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Roach
# |   |   |   |   |   |   |--- feature_5 >  4.14
# |   |   |   |   |   |   |   |--- feature_4 <= 7.98
# |   |   |   |   |   |   |   |   |--- class: Perch
# |   |   |   |   |   |   |   |--- feature_4 >  7.98
# |   |   |   |   |   |   |   |   |--- feature_3 <= 29.00
# |   |   |   |   |   |   |   |   |   |--- class: Perch
# |   |   |   |   |   |   |   |   |--- feature_3 >  29.00
# |   |   |   |   |   |   |   |   |   |--- class: Whitefish
# |   |   |   |   |   |--- feature_4 >  8.35
# |   |   |   |   |   |   |--- feature_3 <= 29.10
# |   |   |   |   |   |   |   |--- feature_5 <= 4.24
# |   |   |   |   |   |   |   |   |--- class: Parkki
# |   |   |   |   |   |   |   |--- feature_5 >  4.24
# |   |   |   |   |   |   |   |   |--- class: Whitefish
# |   |   |   |   |   |   |--- feature_3 >  29.10
# |   |   |   |   |   |   |   |--- feature_4 <= 10.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 8.83
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 25.30
# |   |   |   |   |   |   |   |   |   |   |--- class: Roach
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  25.30
# |   |   |   |   |   |   |   |   |   |   |--- class: Whitefish
# |   |   |   |   |   |   |   |   |--- feature_4 >  8.83
# |   |   |   |   |   |   |   |   |   |--- class: Roach
# |   |   |   |   |   |   |   |--- feature_4 >  10.50
# |   |   |   |   |   |   |   |   |--- class: Bream
# |   |   |   |   |--- feature_2 >  32.00
# |   |   |   |   |   |--- class: Pike
# |   |   |   |--- feature_5 >  5.68
# |   |   |   |   |--- feature_2 <= 31.90
# |   |   |   |   |   |--- class: Whitefish
# |   |   |   |   |--- feature_2 >  31.90
# |   |   |   |   |   |--- feature_5 <= 6.60
# |   |   |   |   |   |   |--- feature_4 <= 11.45
# |   |   |   |   |   |   |   |--- class: Perch
# |   |   |   |   |   |   |--- feature_4 >  11.45
# |   |   |   |   |   |   |   |--- class: Whitefish
# |   |   |   |   |   |--- feature_5 >  6.60
# |   |   |   |   |   |   |--- class: Perch
# |   |   |--- feature_3 >  47.30
# |   |   |   |--- class: Pike
# |--- feature_4 >  12.64
# |   |--- feature_0 <= 1050.00
# |   |   |--- class: Bream
# |   |--- feature_0 >  1050.00
# |   |   |--- class: Perch

# %%
fig = plt.figure(figsize=(25,20))
q = tree.plot_tree(clf,feature_names=data.Species,filled=True)

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# %%
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6875

# %%
# !pip install graphviz
# !pip install pydotplus
# !pip install six
# Out:
# Requirement already satisfied: graphviz in c:\users\likhit reddy\anaconda3\lib\site-packages (0.16)
# Requirement already satisfied: pydotplus in c:\users\likhit reddy\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\likhit reddy\anaconda3\lib\site-packages (from pydotplus) (2.4.7)
# Requirement already satisfied: six in c:\users\likhit reddy\anaconda3\lib\site-packages (1.15.0)

# %%
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, 
                feature_names = ['Weight', 'Length1', 'Length2', 'Length3', 'Height','Width'],
                class_names=['0','1','2'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('data.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-ea60c606e3d8> in <module>
#       1 dot_data = StringIO()
# ----> 2 export_graphviz(clf, out_file=dot_data,
#       3                 filled=True, rounded=True,
#       4                 special_characters=True,
#       5                 feature_names = ['Weight', 'Length1', 'Length2', 'Length3', 'Height','Width'],
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     781             rounded=rounded, special_characters=special_characters,
#     782             precision=precision)
# --> 783         exporter.export(decision_tree)
#     784
#     785         if return_string:
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in export(self, decision_tree)
#     421             self.recurse(decision_tree, 0, criterion="impurity")
#     422         else:
# --> 423             self.recurse(decision_tree.tree_, 0,
#     424                          criterion=decision_tree.criterion)
#     425
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     505
#     506             if left_child != _tree.TREE_LEAF:
# --> 507                 self.recurse(tree, left_child, criterion=criterion,
#     508                              parent=node_id, depth=depth + 1)
#     509                 self.recurse(tree, right_child, criterion=criterion,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     505
#     506             if left_child != _tree.TREE_LEAF:
# --> 507                 self.recurse(tree, left_child, criterion=criterion,
#     508                              parent=node_id, depth=depth + 1)
#     509                 self.recurse(tree, right_child, criterion=criterion,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     505
#     506             if left_child != _tree.TREE_LEAF:
# --> 507                 self.recurse(tree, left_child, criterion=criterion,
#     508                              parent=node_id, depth=depth + 1)
#     509                 self.recurse(tree, right_child, criterion=criterion,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     481
#     482             self.out_file.write(
# --> 483                 '%d [label=%s' % (node_id, self.node_to_str(tree, node_id,
#     484                                                             criterion)))
#     485
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in node_to_str(self, tree, node_id, criterion)
#     352                 node_string += 'class = '
#     353             if self.class_names is not True:
# --> 354                 class_name = self.class_names[np.argmax(value)]
#     355             else:
#     356                 class_name = "y%s%s%s" % (characters[1],
#
# IndexError: list index out of range
